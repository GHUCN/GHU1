# %%
import nltk
import spacy
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer , WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = "I am running and eating at the same time. I have better habits now."

# --- NLTK ---
tokens = word_tokenize(text)

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

stemmed = [stemmer.stem(word) for word in tokens]
lemmatized = [lemmatizer.lemmatize(word) for word in tokens]

print("NLTK Tokens:", tokens)
print("Stemmed:", stemmed)
print("Lemmatized:", lemmatized)

# --- spaCy ---
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

spacy_tokens = [token.text for token in doc]
spacy_lemmas = [token.lemma_ for token in doc]

print("spaCy Tokens:", spacy_tokens)
print("spaCy Lemmas:", spacy_lemmas)
# Out:
# NLTK Tokens: ['I', 'am', 'running', 'and', 'eating', 'at', 'the', 'same', 'time', '.', 'I', 'have', 'better', 'habits', 'now', '.']
# Stemmed: ['i', 'am', 'run', 'and', 'eat', 'at', 'the', 'same', 'time', '.', 'i', 'have', 'better', 'habit', 'now', '.']
# Lemmatized: ['I', 'am', 'running', 'and', 'eating', 'at', 'the', 'same', 'time', '.', 'I', 'have', 'better', 'habit', 'now', '.']
# spaCy Tokens: ['I', 'am', 'running', 'and', 'eating', 'at', 'the', 'same', 'time', '.', 'I', 'have', 'better', 'habits', 'now', '.']
# spaCy Lemmas: ['I', 'be', 'run', 'and', 'eat', 'at', 'the', 'same', 'time', '.', 'I', 'have', 'well', 'habit', 'now', '.']
