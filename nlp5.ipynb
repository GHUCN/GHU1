# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# Naive Bayes
nb = MultinomialNB()
nb.fit(X_train_vectorized, y_train_data)
y_pred_nb = nb.predict(X_test_vectorized)
print("Naive Bayes Classifier:")
print(f"Accuracy: {nb.score(X_test_vectorized, y_test_data) * 100:.2f}%")
print("Classification Report:")
print(classification_report(y_test_data, y_pred_nb))
print("Confusion Matrix:\n", confusion_matrix(y_test_data, y_pred_nb))

# SVM
svm = SVC(random_state=42)
svm.fit(X_train_vectorized, y_train_data)
y_pred_svm = svm.predict(X_test_vectorized)
print("\nSupport Vector Machine Classifier:")
print(f"Accuracy: {svm.score(X_test_vectorized, y_test_data) * 100:.2f}%")
print("Classification Report:")
print(classification_report(y_test_data, y_pred_svm))
print("Confusion Matrix:\n", confusion_matrix(y_test_data, y_pred_svm))
# Out:
# Naive Bayes Classifier:
# Accuracy: 98.74%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       966
#            1       0.99      0.92      0.95       149
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.96      0.97      1115
# weighted avg       0.99      0.99      0.99      1115
#
# Confusion Matrix:
#  [[964   2]
#  [ 12 137]]
#
# Support Vector Machine Classifier:
# Accuracy: 97.67%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       966
#            1       0.99      0.83      0.91       149
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.92      0.95      1115
# weighted avg       0.98      0.98      0.98      1115
#
# Confusion Matrix:
#  [[965   1]
#  [ 25 124]]

# %%
# !wget -nc https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip
# !unzip -n smsspamcollection.zip

import pandas as pd

# Load the dataset
df = pd.read_csv('SMSSpamCollection', sep='\t', header=None, names=['label', 'message'])

# Display the first few rows and information
display(df.head())
display(df.info())
display(df['label'].value_counts())

# %%
from sklearn.metrics import classification_report, confusion_matrix
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

X_data = df['message']
y_data = df['label']

X_train_raw, X_test_raw, y_train_data, y_test_data = train_test_split(X_data, y_data, test_size=0.2, random_state=42, stratify=y_data)

vectorizer = CountVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train_raw)
X_test_vectorized = vectorizer.transform(X_test_raw)

print("Data preprocessing complete. Ready for model training.")
# Out:
# Data preprocessing complete. Ready for model training.
